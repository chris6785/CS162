# %%
import matplotlib.pyplot as plot

# %%
numlist = [7, 10, 6, 4]
namelist = ['Junior', 'Sophomores', 'Freshman', 'Seniors']

# %%
colorlist = ['orange', 'red', 'cyan', 'yellow' ]
explodelist = [0.0, 0.1, 0.0, 0.0]

# %%
plot.pie(numlist, labels=namelist, autopct='%.1f%%', colors=colorlist, explode = explodelist, startangle = 292,
         shadow = True, wedgeprops={'edgecolor': 'black', 'linewidth': 0.5},
         textprops={'fontsize': 12, 'fontweight': 'bold'}, radius=1.25)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ed9f6167fd0>,
#   <matplotlib.patches.Wedge at 0x7ed9f54cbed0>,
#   <matplotlib.patches.Wedge at 0x7ed9f63a1950>,
#   <matplotlib.patches.Wedge at 0x7ed9f618a550>],
#  [Text(1.280784632350562, -0.5002156790171969, 'Junior'),
#   Text(-0.051476650290923645, 1.4741014736017415, 'Sophomores'),
#   Text(-1.302670430002159, -0.44008493589077824, 'Freshman'),
#   Text(-0.11186831073054258, -1.3704417101994142, 'Seniors')],
#  [Text(0.698609799463943, -0.272844915827562, '25.9%'),
#   Text(-0.02966451033714244, 0.8494822051264272, '37.0%'),
#   Text(-0.7105475072739049, -0.2400463286676972, '22.2%'),
#   Text(-0.061019078580295955, -0.7475136601087713, '14.8%')])

# %%
plot.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
plot.savefig('./piechart.png')
